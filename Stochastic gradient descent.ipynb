# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
w = np.arange(-10, 14 , 0.1)
loss = w**2 - 4*w
point  = -5


plt.plot(w  , loss)
plt.plot(point , point**2 -  4*point , 'ro')
plt.title('Loss Function')
# Out:
# Text(0.5, 1.0, 'Loss Function')

# %%
def gradient_descent(df=lambda w: 2*w - 4 ,lr = 0.01 , w_0 = -5  , max_iters = 10000 , precision = 0.000001):

    # licznik iteracji
    iters  = 0
